# %% [markdown]
# # Laporan Kelompok 7 - Car Counting
#
# Dataset : [Dataset](http://bit.ly/2ZujQaD)
#
# *   Aditya Raybol Saragih
# *   Yanuar Pratama Pandjaitan
# *   Muhammad Luthvan Hood
# *   Akmal Hugo Prasetyo
# *   Lutfi Rizky Ramadhan

# %% [markdown]
# Koneksi dengan Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# *Clone* GitHub yang sudah dimodifikasi

# %%
# !git clone https://github.com/Ltfrzky/tensorflow_object_counting_api yolo
# Out:
# Cloning into 'yolo'...
# remote: Enumerating objects: 107, done.
# remote: Counting objects: 100% (107/107), done.
# remote: Compressing objects: 100% (92/92), done.
# remote: Total 1038 (delta 41), reused 67 (delta 13), pack-reused 931
# Receiving objects: 100% (1038/1038), 331.89 MiB | 31.44 MiB/s, done.
# Resolving deltas: 100% (483/483), done.

# %% [markdown]
# masuk ke dalam folder github yang dibuat

# %%
# %cd yolo
# Out:
# /content/yolo

# %%
# !ls
# Out:
# api			       protos
# CONTRIBUTING.md		       README.md
# custom_frozen_inference_graph  requirements.txt
# data			       ssd_mobilenet_v1_coco_2018_01_28
# input			       utils
# LICENSE			       vehicle_counting.py
# output

# %% [markdown]
# download faster rcnn resnet50

# %%
#!wget http://download.tensorflow.org/models/object_detection/faster_rcnn_resnet50_coco_2018_01_28.tar.gz

# %% [markdown]
# extract faster rcnn resnet50

# %%
#!tar xvzf faster_rcnn_resnet50_coco_2018_01_28.tar.gz

# %% [markdown]
# copy file video yang ingin dilakukan detection/counting

# %%
# !cp -r /content/drive/My\ Drive/YOLO/input/highwaylow.mp4 ./input

# %% [markdown]
# run the detection/counting

# %%
# !python ./vehicle_counting.py -i ./input/highwaylow.mp4 -o output/mobilenet_teslow.avi
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0821 02:04:07.067793 139843675174784 deprecation_wrapper.py:119] From /content/yolo/utils/backbone.py:38: The name tf.GraphDef is deprecated. Please use tf.compat.v1.GraphDef instead.
#
# W0821 02:04:07.069074 139843675174784 deprecation_wrapper.py:119] From /content/yolo/utils/backbone.py:39: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# W0821 02:04:08.087718 139843675174784 deprecation_wrapper.py:119] From /content/yolo/api/object_counting_api.py:149: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2019-08-21 02:04:08.090571: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcuda.so.1
# 2019-08-21 02:04:08.116164: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# ...

# %% [markdown]
# Copy hasil/output detection ke dalam Google Drive

# %%
# !cp -r ./output/mobilenet_teslow.avi /content/drive/My\ Drive/YOLO/video
